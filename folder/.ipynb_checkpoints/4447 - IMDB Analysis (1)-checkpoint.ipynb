# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

import cpi
# cpi.update()

# %%
imdb_movies = pd.read_csv('IMDb movies.csv')
imdb_movies.head()
# Out:
# /home/daniel/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
imdb_ratings = pd.read_csv('IMDb ratings.csv')
imdb_ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                 13.0                     4.5                  4.0
# 1                 23.0                     6.6                 14.0
# 2                  4.0                     6.8                  7.0
# 3                 14.0                     6.1                 21.0
# 4                 82.0                     7.4                 77.0
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    5.7                  34.0               6.4
# 1                    6.4                  66.0               6.0
# 2                    5.4                  32.0               6.2
# 3                    4.9                  57.0               5.5
# 4                    6.9                 139.0               7.0
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# 0             51.0                   6.0                 70.0
# 1             96.0                   6.2                331.0
# 2             31.0                   5.9                123.0
# 3            207.0                   4.7                105.0
# 4            488.0                   7.0               1166.0
#
# [5 rows x 49 columns]

# %%
movies = pd.merge(imdb_movies, imdb_ratings, on = 'imdb_title_id')

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ... females_30age_avg_vote  \
# 0     None                      Alexander Black  ...                    5.7
# 1     None                         Charles Tait  ...                    6.2
# 2      NaN                            Urban Gad  ...                    5.8
# 3  English                   Charles L. Gaskill  ...                    5.5
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...                    7.3
#
#   females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                13.0                    4.5                 4.0
# 1                23.0                    6.6                14.0
# 2                 4.0                    6.8                 7.0
# 3                14.0                    6.1                21.0
# 4                82.0                    7.4                77.0
#
#    top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                    5.7                  34.0              6.4
# 1                    6.4                  66.0              6.0
# 2                    5.4                  32.0              6.2
# 3                    4.9                  57.0              5.5
# 4                    6.9                 139.0              7.0
#
#   us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0            51.0                  6.0                 70.0
# 1            96.0                  6.2                331.0
# 2            31.0                  5.9                123.0
# 3           207.0                  4.7                105.0
# 4           488.0                  7.0               1166.0
#
# [5 rows x 70 columns]

# %%
movies_usa = movies[movies['country'] == 'USA']
movies_usa.sample(10)
# Out:
#       imdb_title_id                          title  \
# 74904     tt4513674                   Café Society
# 61196     tt1715873                       10 Years
# 10214     tt0053610  Atlas il trionfatore di Atene
# 61331     tt1727252                     Chillerama
# 494       tt0016971                His First Flame
# 4652      tt0036602    Andy Hardy's Blonde Trouble
# 7560      tt0045754                   Fast Company
# 27868     tt0109196          Giustizia clandestina
# 1692      tt0024620     Il ritorno della straniera
# 33811     tt0163069              Oltre ogni limite
#
#                     original_title  year date_published  \
# 74904                 Café Society  2016     2016-09-29
# 61196                     10 Years  2011     2012-10-05
# 10214                        Atlas  1961     1961-05-01
# 61331                   Chillerama  2011     2011-08-22
# 494                His First Flame  1927     1927-05-03
# 4652   Andy Hardy's Blonde Trouble  1944     1945-01-26
# 7560                  Fast Company  1953     1953-05-22
# 27868           Backstreet Justice  1994     1994-08-12
# 1692         The Stranger's Return  1933     1934-09-01
# 33811               Losing Control  1998           1998
#
#                             genre  duration country         language  \
# 74904      Comedy, Drama, Romance        96     USA  English, Hebrew
# 61196      Comedy, Drama, Romance       110     USA          English
# 10214    Action, Adventure, Drama        79     USA          English
# 61331      Action, Comedy, Horror       120     USA          English
# 494                        Comedy        48     USA          English
# 4652              Comedy, Romance       107     USA          English
# 7560                       Comedy        67     USA          English
# 27868                Crime, Drama        91     USA          English
# 1692                Comedy, Drama        89     USA          English
# 33811  Mystery, Romance, Thriller        93     USA          English
#
#                     director  ... females_30age_avg_vote females_30age_votes  \
# 74904            Woody Allen  ...                    6.4              6588.0
# 61196           Jamie Linden  ...                    6.0              4045.0
# 10214           Roger Corman  ...                    5.0                 1.0
# 61331  Adam Green, Joe Lynch  ...                    5.6               256.0
# 494            Harry Edwards  ...                    7.7                 3.0
# 4652         George B. Seitz  ...                    6.9                24.0
# 7560            John Sturges  ...                    5.7                 5.0
# 27868         Chris McIntyre  ...                    3.6                 7.0
# 1692              King Vidor  ...                    6.9                14.0
# 33811           Julie Jordan  ...                    5.0                 8.0
#
#       females_45age_avg_vote females_45age_votes  top1000_voters_rating  \
# 74904                    6.6              1400.0                    6.0
# 61196                    5.9               574.0                    5.3
# 10214                    4.0                 7.0                    4.5
# 61331                    5.6                83.0                    4.9
# 494                      7.3                 3.0                    5.9
# 4652                     7.1                44.0                    6.3
# 7560                     5.2                12.0                    5.5
# 27868                    4.2                 9.0                    4.6
# 1692                     6.7                45.0                    6.7
# 33811                    5.2                 4.0                    4.5
#
#        top1000_voters_votes us_voters_rating us_voters_votes  \
# 74904                 347.0              6.6          7139.0
# 61196                 197.0              6.2          4172.0
# 10214                  44.0              4.3           106.0
# 61331                 115.0              5.8          1379.0
# 494                    19.0              6.0            47.0
# 4652                   68.0              6.7           275.0
# 7560                   61.0              5.2            72.0
# 27868                  49.0              4.4            96.0
# 1692                   58.0              6.9           210.0
# 33811                  31.0              4.6            76.0
#
#       non_us_voters_rating  non_us_voters_votes
# 74904                  6.6              33601.0
# 61196                  6.1              11291.0
# 10214                  3.7                 35.0
# 61331                  5.5               1753.0
# 494                    5.9                 47.0
# 4652                   6.4                 73.0
# 7560                   5.6                 43.0
# 27868                  4.6                 87.0
# 1692                   6.7                102.0
# 33811                  4.0                124.0
#
# [10 rows x 70 columns]

# %%
pd.options.display.max_rows = 999
print(str(movies_usa.isna().sum()))
# Out:
# imdb_title_id                    0
# title                            0
# original_title                   0
# year                             0
# date_published                   0
# genre                            0
# duration                         0
# country                          0
# language                       345
# director                        34
# writer                         201
# production_company            1160
# actors                          26
# description                     74
# avg_vote                         0
# votes                            0
# budget                       18023
# usa_gross_income             20947
# worlwide_gross_income        20808
# metascore                    21902
# reviews_from_users             305
# reviews_from_critics          1876
# weighted_average_vote            0
# total_votes                      0
# mean_vote                        0
# median_vote                      0
# votes_10                         0
# votes_9                          0
# votes_8                          0
# votes_7                          0
# votes_6                          0
# votes_5                          0
# votes_4                          0
# votes_3                          0
# votes_2                          0
# votes_1                          0
# allgenders_0age_avg_vote     15700
# allgenders_0age_votes        15700
# allgenders_18age_avg_vote      335
# allgenders_18age_votes         335
# allgenders_30age_avg_vote        0
# allgenders_30age_votes           0
# allgenders_45age_avg_vote        1
# allgenders_45age_votes           1
# males_allages_avg_vote           1
# males_allages_votes              1
# males_0age_avg_vote          18261
# males_0age_votes             18261
# males_18age_avg_vote           755
# males_18age_votes              755
# males_30age_avg_vote             2
# males_30age_votes                2
# males_45age_avg_vote             2
# males_45age_votes                2
# females_allages_avg_vote         7
# females_allages_votes            7
# females_0age_avg_vote        18721
# females_0age_votes           18721
# females_18age_avg_vote        2162
# females_18age_votes           2162
# females_30age_avg_vote         180
# females_30age_votes            180
# females_45age_avg_vote         146
# females_45age_votes            146
# top1000_voters_rating           14
# top1000_voters_votes            14
# us_voters_rating                 2
# us_voters_votes                  2
# non_us_voters_rating             1
# non_us_voters_votes              1
# dtype: int64

# %%
movies_usa.shape
# Out:
# (28511, 70)

# %%
select =  ['imdb_title_id',
           'title',
           'original_title',
           'year',
           'date_published',
           'genre',
           'director',
           'avg_vote',
           'votes',
           'budget',
           'males_allages_avg_vote',
           'males_allages_votes',
           'females_allages_avg_vote',
           'females_allages_votes']

movies_usa = movies_usa[select]

# %% [markdown]
# Graphing Stuff

# %%
pd.options.display.max_columns = 999
cleaned = movies_usa.genre.str.split(",", expand=True).stack()
pd.get_dummies(cleaned).groupby(level=0).sum()
movies_usa["genre"] = movies_usa.genre.apply(lambda x: x.replace(" ", ""))
movies_usa = pd.concat([movies_usa, movies_usa["genre"].str.get_dummies(',')], axis = 1)
movies_usa.head()
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 3      tt0002101                                          Cleopatra
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 17     tt0003167                                     Amore di madre
# 19     tt0003471                                   Traffic in Souls
#
#                                        original_title  year date_published  \
# 0                                          Miss Jerry  1894     1894-10-09
# 3                                           Cleopatra  1912     1912-11-13
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# 17                                   Home, Sweet Home  1914     1914-05-17
# 19                                   Traffic in Souls  1913     1913-11-24
#
#               genre             director  avg_vote  votes   budget  \
# 0           Romance      Alexander Black       5.9    154      NaN
# 3     Drama,History   Charles L. Gaskill       5.2    446  $ 45000
# 5   Biography,Drama        Sidney Olcott       5.7    484      NaN
# 17            Drama        D.W. Griffith       5.8    187      NaN
# 19      Crime,Drama  George Loane Tucker       6.0    552   $ 5700
#
#     males_allages_avg_vote  males_allages_votes  females_allages_avg_vote  \
# 0                      6.2                 97.0                       6.0
# 3                      5.1                299.0                       5.9
# 5                      5.7                354.0                       5.8
# 17                     5.7                124.0                       6.4
# 19                     5.9                399.0                       6.5
#
#     females_allages_votes  Action  Adventure  Animation  Biography  Comedy  \
# 0                    35.0       0          0          0          0       0
# 3                    39.0       0          0          0          0       0
# 5                    31.0       0          0          0          1       0
# 17                   16.0       0          0          0          0       0
# 19                   54.0       0          0          0          0       0
#
#     Crime  Documentary  Drama  Family  Fantasy  Film-Noir  History  Horror  \
# 0       0            0      0       0        0          0        0       0
# 3       0            0      1       0        0          0        1       0
# 5       0            0      1       0        0          0        0       0
# 17      0            0      1       0        0          0        0       0
# 19      1            0      1       0        0          0        0       0
#
#     Music  Musical  Mystery  News  Reality-TV  Romance  Sci-Fi  Sport  \
# 0       0        0        0     0           0        1       0      0
# 3       0        0        0     0           0        0       0      0
# 5       0        0        0     0           0        0       0      0
# 17      0        0        0     0           0        0       0      0
# 19      0        0        0     0           0        0       0      0
#
#     Thriller  War  Western
# 0          0    0        0
# 3          0    0        0
# 5          0    0        0
# 17         0    0        0
# 19         0    0        0

# %%
small = movies_usa.iloc[:,12:]

# %%
#looking at avg rating per genre
sum_per_genre = (
    movies_usa.assign(genres=movies_usa["genre"].str.split(", "))
)
sep = '*'

# %%
avg_per_genre = (
    movies_usa.assign(genres=movies_usa["genre"].str.split(","))
    .explode("genres")
    .groupby("genres", as_index=False)["avg_vote"].mean()
)
count_per_genre = (
    movies_usa.assign(genres=movies_usa["genre"].str.split(","))
    .explode("genres")
    .groupby("genres", as_index=False)["title"].count()
)
metrics_per_genre = pd.concat([avg_per_genre, count_per_genre["title"]], axis = 1)
metrics_per_genre = metrics_per_genre[metrics_per_genre["title"] != 1]
metrics_per_genre.rename({"title":"count"}, axis = 1, inplace = True)
metrics_per_genre
# Out:
#        genres  avg_vote  count
# 0      Action  5.250176   4273
# 1   Adventure  5.711773   2854
# 2   Animation  6.256481    432
# 3   Biography  6.544744    704
# 4      Comedy  5.680094   9972
# 5       Crime  5.810991   4267
# 7       Drama  5.930578  13827
# 8      Family  5.658366   1285
# 9     Fantasy  5.345362   1175
# 10  Film-Noir  6.642968    647
# 11    History  6.371982    439
# 12     Horror  4.487603   4590
# 13      Music  6.031728    810
# 14    Musical  6.145011    902
# 15    Mystery  5.590010   2012
# 18    Romance  6.036835   5131
# 19     Sci-Fi  4.762232   1774
# 20      Sport  5.884146    492
# 21   Thriller  5.008033   4382
# 22        War  6.142968    647
# 23    Western  6.004348   1127

# %%
g = sns.barplot(data=metrics_per_genre, x= "genres", y = "avg_vote")
g.set_xticklabels(g.get_xticklabels(), 
                          rotation=90, 
                          horizontalalignment='right')
g.set_ylabel("Average Rating")
g.set_title("Rating per Genre");

# %%
avg_per_director = (
    movies_usa.assign(directors=movies_usa["director"].str.split(","))
    .explode("directors")
    .groupby("directors", as_index=False)["avg_vote"].mean()
)
count_per_director = (
    movies_usa.assign(directors=movies_usa["director"].str.split(","))
    .explode("directors")
    .groupby("directors", as_index=False)["title"].count()
)

metrics_dir = pd.concat([avg_per_director, count_per_director["title"]], axis = 1)
#metrics_dir = metrics_per_genre[metrics_per_genre["title"] != 1]
metrics_dir.rename({"title":"count"}, axis = 1, inplace = True)
metrics_dir = metrics_dir.sort_values("avg_vote", axis = 0, ascending=False)
metrics_dir = metrics_dir[metrics_dir["count"] >= 5]
metrics_dir
# Out:
#                 directors  avg_vote  count
# 10339   Quentin Tarantino  7.811111      9
# 3179      Charles Chaplin  7.666667     15
# 4075        David Fincher  7.625000      8
# 2580         Billy Wilder  7.580952     21
# 670             Joe Russo  7.580000      5
# ...                   ...       ...    ...
# 4493        Donald Farmer  2.483333      6
# 2563           Bill Zebub  2.483333      6
# 8692         Mark Polonia  2.377778      9
# 1981      Andrew Bellware  2.220000      5
# 3437   Christopher Forbes  2.000000      7
#
# [1195 rows x 3 columns]

# %%
top5 = metrics_dir["directors"].values.tolist()
top5 = top5[0:4] 
movies_small = movies_usa[movies_usa["director"].isin(top5)]

table = pd.pivot_table(movies_small, index = ["director", "year"], values = ["avg_vote"])
g = sns.lineplot(data=table.reset_index(), x = "year", y = "avg_vote", hue = "director")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid()
g.set(xlabel='Year', ylabel='Rating')
g.set_title("Director's Ratings Over Time");

# %% [markdown]
# Convert to date time

# %%
movies_usa['date_published'] = pd.to_datetime(movies_usa['date_published'], format='%Y-%m-%d', errors = 'coerce' )
movies_usa.dtypes
# Out:
# imdb_title_id                       object
# title                               object
# original_title                      object
# year                                object
# date_published              datetime64[ns]
# genre                               object
# director                            object
# avg_vote                           float64
# votes                                int64
# budget                              object
# males_allages_avg_vote             float64
# males_allages_votes                float64
# females_allages_avg_vote           float64
# females_allages_votes              float64
# Action                               int64
# Adventure                            int64
# Animation                            int64
# Biography                            int64
# Comedy                               int64
# Crime                                int64
# Documentary                          int64
# Drama                                int64
# Family                               int64
# Fantasy                              int64
# Film-Noir                            int64
# History                              int64
# Horror                               int64
# Music                                int64
# Musical                              int64
# Mystery                              int64
# News                                 int64
# Reality-TV                           int64
# Romance                              int64
# Sci-Fi                               int64
# Sport                                int64
# Thriller                             int64
# War                                  int64
# Western                              int64
# dtype: object

# %%
def convert_budget(row):
    if pd.isnull(row['budget']):
        return np.nan
    year = row['year'] if isinstance(row['year'], int) else  int(re.search(r'[0-9]{4}',row['year']).group(0))
    
    if not year in range(1913,2020) :
        return np.nan
    
    if '$' in row['budget']:
        budget = int(row['budget'].replace('$', ''))
        return cpi.inflate(budget, year)
    else:
        return np.nan

# %%
movies_usa['adjusted_budget'] = movies_usa.apply(convert_budget, axis = 1)

# %%
movies_usa.head()
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 3      tt0002101                                          Cleopatra
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 17     tt0003167                                     Amore di madre
# 19     tt0003471                                   Traffic in Souls
#
#                                        original_title  year date_published  \
# 0                                          Miss Jerry  1894     1894-10-09
# 3                                           Cleopatra  1912     1912-11-13
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912     1913-01-01
# 17                                   Home, Sweet Home  1914     1914-05-17
# 19                                   Traffic in Souls  1913     1913-11-24
#
#               genre             director  avg_vote  votes   budget  \
# 0           Romance      Alexander Black       5.9    154      NaN
# 3     Drama,History   Charles L. Gaskill       5.2    446  $ 45000
# 5   Biography,Drama        Sidney Olcott       5.7    484      NaN
# 17            Drama        D.W. Griffith       5.8    187      NaN
# 19      Crime,Drama  George Loane Tucker       6.0    552   $ 5700
#
#     males_allages_avg_vote  males_allages_votes  females_allages_avg_vote  \
# 0                      6.2                 97.0                       6.0
# 3                      5.1                299.0                       5.9
# 5                      5.7                354.0                       5.8
# 17                     5.7                124.0                       6.4
# 19                     5.9                399.0                       6.5
#
#     females_allages_votes  Action  Adventure  Animation  Biography  Comedy  \
# 0                    35.0       0          0          0          0       0
# 3                    39.0       0          0          0          0       0
# 5                    31.0       0          0          0          1       0
# 17                   16.0       0          0          0          0       0
# 19                   54.0       0          0          0          0       0
#
#     Crime  Documentary  Drama  Family  Fantasy  Film-Noir  History  Horror  \
# 0       0            0      0       0        0          0        0       0
# 3       0            0      1       0        0          0        1       0
# 5       0            0      1       0        0          0        0       0
# 17      0            0      1       0        0          0        0       0
# 19      1            0      1       0        0          0        0       0
#
#     Music  Musical  Mystery  News  Reality-TV  Romance  Sci-Fi  Sport  \
# 0       0        0        0     0           0        1       0      0
# 3       0        0        0     0           0        0       0      0
# 5       0        0        0     0           0        0       0      0
# 17      0        0        0     0           0        0       0      0
# 19      0        0        0     0           0        0       0      0
#
#     Thriller  War  Western  adjusted_budget
# 0          0    0        0              NaN
# 3          0    0        0              NaN
# 5          0    0        0              NaN
# 17         0    0        0              NaN
# 19         0    0        0    147196.454545

# %%
movies_usa['genre'] = movies_usa['genre'].apply(lambda x: x.replace(' ',''))
movies_usa = pd.concat([movies_usa, movies_usa['genre'].str.get_dummies(',')], axis = 1)
movies_usa.head()
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 3      tt0002101                                          Cleopatra
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 17     tt0003167                                     Amore di madre
# 19     tt0003471                                   Traffic in Souls
#
#                                        original_title  year date_published  \
# 0                                          Miss Jerry  1894     1894-10-09
# 3                                           Cleopatra  1912     1912-11-13
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912     1913-01-01
# 17                                   Home, Sweet Home  1914     1914-05-17
# 19                                   Traffic in Souls  1913     1913-11-24
#
#               genre             director  avg_vote  votes   budget  \
# 0           Romance      Alexander Black       5.9    154      NaN
# 3     Drama,History   Charles L. Gaskill       5.2    446  $ 45000
# 5   Biography,Drama        Sidney Olcott       5.7    484      NaN
# 17            Drama        D.W. Griffith       5.8    187      NaN
# 19      Crime,Drama  George Loane Tucker       6.0    552   $ 5700
#
#     males_allages_avg_vote  males_allages_votes  females_allages_avg_vote  \
# 0                      6.2                 97.0                       6.0
# 3                      5.1                299.0                       5.9
# 5                      5.7                354.0                       5.8
# 17                     5.7                124.0                       6.4
# 19                     5.9                399.0                       6.5
#
#     females_allages_votes  Action  Adventure  Animation  Biography  Comedy  \
# 0                    35.0       0          0          0          0       0
# 3                    39.0       0          0          0          0       0
# 5                    31.0       0          0          0          1       0
# 17                   16.0       0          0          0          0       0
# 19                   54.0       0          0          0          0       0
#
#     Crime  Documentary  Drama  Family  Fantasy  Film-Noir  History  Horror  \
# 0       0            0      0       0        0          0        0       0
# 3       0            0      1       0        0          0        1       0
# 5       0            0      1       0        0          0        0       0
# 17      0            0      1       0        0          0        0       0
# 19      1            0      1       0        0          0        0       0
#
#     Music  Musical  Mystery  News  Reality-TV  Romance  Sci-Fi  Sport  \
# 0       0        0        0     0           0        1       0      0
# 3       0        0        0     0           0        0       0      0
# 5       0        0        0     0           0        0       0      0
# 17      0        0        0     0           0        0       0      0
# 19      0        0        0     0           0        0       0      0
#
#     Thriller  War  Western  adjusted_budget  Action  Adventure  Animation  \
# 0          0    0        0              NaN       0          0          0
# 3          0    0        0              NaN       0          0          0
# 5          0    0        0              NaN       0          0          0
# 17         0    0        0              NaN       0          0          0
# 19         0    0        0    147196.454545       0          0          0
#
#     Biography  Comedy  Crime  Documentary  Drama  Family  Fantasy  Film-Noir  \
# 0           0       0      0            0      0       0        0          0
# 3           0       0      0            0      1       0        0          0
# 5           1       0      0            0      1       0        0          0
# 17          0       0      0            0      1       0        0          0
# 19          0       0      1            0      1       0        0          0
#
#     History  Horror  Music  Musical  Mystery  News  Reality-TV  Romance  \
# 0         0       0      0        0        0     0           0        1
# 3         1       0      0        0        0     0           0        0
# 5         0       0      0        0        0     0           0        0
# 17        0       0      0        0        0     0           0        0
# 19        0       0      0        0        0     0           0        0
#
#     Sci-Fi  Sport  Thriller  War  Western
# 0        0      0         0    0        0
# 3        0      0         0    0        0
# 5        0      0         0    0        0
# 17       0      0         0    0        0
# 19       0      0         0    0        0

# %%
print(str(movies_usa.isna().sum()))
# Out:
# imdb_title_id                   0
# title                           0
# original_title                  0
# year                            0
# date_published                  1
# genre                           0
# director                       34
# avg_vote                        0
# votes                           0
# budget                      18023
# males_allages_avg_vote          1
# males_allages_votes             1
# females_allages_avg_vote        7
# females_allages_votes           7
# Action                          0
# Adventure                       0
# Animation                       0
# Biography                       0
# Comedy                          0
# Crime                           0
# Documentary                     0
# Drama                           0
# Family                          0
# Fantasy                         0
# Film-Noir                       0
# History                         0
# Horror                          0
# Music                           0
# Musical                         0
# Mystery                         0
# News                            0
# Reality-TV                      0
# Romance                         0
# Sci-Fi                          0
# Sport                           0
# Thriller                        0
# War                             0
# Western                         0
# adjusted_budget             18090
# Action                          0
# Adventure                       0
# Animation                       0
# Biography                       0
# Comedy                          0
# Crime                           0
# Documentary                     0
# Drama                           0
# Family                          0
# Fantasy                         0
# Film-Noir                       0
# History                         0
# Horror                          0
# Music                           0
# Musical                         0
# Mystery                         0
# News                            0
# Reality-TV                      0
# Romance                         0
# Sci-Fi                          0
# Sport                           0
# Thriller                        0
# War                             0
# Western                         0
# dtype: int64
