# %%
! pip install numpy

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.1.4-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 6.7 MB/s eta 0:00:01
# Collecting numpy>=1.15.4
#   Downloading numpy-1.19.4-cp36-cp36m-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 5.7 MB/s eta 0:00:01
# Collecting pytz>=2017.2
#   Downloading pytz-2020.4-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 7.3 MB/s eta 0:00:01
# Collecting python-dateutil>=2.7.3
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting six>=1.5
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: numpy, pytz, six, python-dateutil, pandas
# Successfully installed numpy-1.19.4 pandas-1.1.4 python-dateutil-2.8.1 pytz-2020.4 six-1.15.0

# %%
print("hi")
print("h")
# Out:
# hi
# h

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
imdb_movies = pd.read_csv('IMDb movies.csv')
imdb_movies.head()
# Out:
# /home/luis/comp_4447/p_env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director          ...           \
# 0     None                      Alexander Black          ...
# 1     None                         Charles Tait          ...
# 2      NaN                            Urban Gad          ...
# 3  English                   Charles L. Gaskill          ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan          ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
imdb_ratings = pd.read_csv('IMDb ratings.csv')
imdb_ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6         ...           \
# 0        12        4       10       43       28         ...
# 1        57       18       58      137      139         ...
# 2         6        6       17       44       52         ...
# 3        15        8       16       62       98         ...
# 4       210      225      436      641      344         ...
#
#    females_30age_avg_vote  females_30age_votes  females_45age_avg_vote  \
# 0                     5.7                 13.0                     4.5
# 1                     6.2                 23.0                     6.6
# 2                     5.8                  4.0                     6.8
# 3                     5.5                 14.0                     6.1
# 4                     7.3                 82.0                     7.4
#
#    females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 0                  4.0                    5.7                  34.0
# 1                 14.0                    6.4                  66.0
# 2                  7.0                    5.4                  32.0
# 3                 21.0                    4.9                  57.0
# 4                 77.0                    6.9                 139.0
#
#    us_voters_rating  us_voters_votes  non_us_voters_rating  \
# 0               6.4             51.0                   6.0
# 1               6.0             96.0                   6.2
# 2               6.2             31.0                   5.9
# 3               5.5            207.0                   4.7
# 4               7.0            488.0                   7.0
#
#    non_us_voters_votes
# 0                 70.0
# 1                331.0
# 2                123.0
# 3                105.0
# 4               1166.0
#
# [5 rows x 49 columns]

# %%
movies = pd.merge(imdb_movies, imdb_ratings, on = 'imdb_title_id')

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ... females_30age_avg_vote  \
# 0     None                      Alexander Black  ...                    5.7
# 1     None                         Charles Tait  ...                    6.2
# 2      NaN                            Urban Gad  ...                    5.8
# 3  English                   Charles L. Gaskill  ...                    5.5
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...                    7.3
#
#   females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                13.0                    4.5                 4.0
# 1                23.0                    6.6                14.0
# 2                 4.0                    6.8                 7.0
# 3                14.0                    6.1                21.0
# 4                82.0                    7.4                77.0
#
#    top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                    5.7                  34.0              6.4
# 1                    6.4                  66.0              6.0
# 2                    5.4                  32.0              6.2
# 3                    4.9                  57.0              5.5
# 4                    6.9                 139.0              7.0
#
#   us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0            51.0                  6.0                 70.0
# 1            96.0                  6.2                331.0
# 2            31.0                  5.9                123.0
# 3           207.0                  4.7                105.0
# 4           488.0                  7.0               1166.0
#
# [5 rows x 70 columns]

# %%
movies_usa = movies[movies['country'] == 'USA']
movies_usa.sample(10)
# Out:
#       imdb_title_id                            title          original_title  \
# 5561      tt0039463                       Alta marea               High Tide
# 61883     tt1778906                   Slew Hampshire          Slew Hampshire
# 39988     tt0281811                         Disaster                Disaster
# 39498     tt0273311                        Killer Me               Killer Me
# 31233     tt0120660                  Nemico pubblico      Enemy of the State
# 71700     tt3548978                      West of Her             West of Her
# 55688     tt1228953                          Big Fan                 Big Fan
# 4597      tt0036377                       Bernadette  The Song of Bernadette
# 14539     tt0065938                      I guerrieri          Kelly's Heroes
# 45175     tt0400717  Boog & Elliot a caccia di amici             Open Season
#
#        year date_published                         genre  duration country  \
# 5561   1947     1947-09-13            Film-Noir, Mystery        72     USA
# 61883  2013     2015-06-06       Drama, Horror, Thriller       103     USA
# 39988  2003     2003-04-17      Action, Adventure, Crime        90     USA
# 39498  2001     2001-09-01     Mystery, Thriller, Horror        80     USA
# 31233  1998     1999-01-15              Action, Thriller       132     USA
# 71700  2016     2018-02-06                Drama, Romance        90     USA
# 55688  2009     2009-01-18          Comedy, Crime, Drama        88     USA
# 4597   1943     1947-05-09              Biography, Drama       156     USA
# 14539  1970     1970-06-23        Adventure, Comedy, War       144     USA
# 45175  2006     2006-12-07  Animation, Adventure, Comedy        86     USA
#
#                       language                   director  ...  \
# 5561                   English             John Reinhardt  ...
# 61883                  English                 Flood Reed  ...
# 39988                  English                 Yossi Wein  ...
# 39498                  English             Zachary Hansen  ...
# 31233                  English                 Tony Scott  ...
# 71700                  English               Ethan Warren  ...
# 55688                  English              Robert Siegel  ...
# 4597           English, French                 Henry King  ...
# 14539  English, French, German            Brian G. Hutton  ...
# 45175                  English  Roger Allers, Jill Culton  ...
#
#       females_30age_avg_vote females_30age_votes females_45age_avg_vote  \
# 5561                     7.3                 5.0                    6.7
# 61883                    5.3                25.0                    4.8
# 39988                    4.3                 8.0                    2.5
# 39498                    5.0                29.0                    5.8
# 31233                    7.2             10360.0                    7.4
# 71700                    5.0                 7.0                    3.7
# 55688                    6.3               277.0                    6.5
# 4597                     7.3               313.0                    7.8
# 14539                    7.5               775.0                    7.5
# 45175                    6.3              6794.0                    6.3
#
#       females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 5561                  8.0                    6.8                  24.0
# 61883                16.0                    3.1                   9.0
# 39988                11.0                    2.6                  21.0
# 39498                47.0                    5.3                  12.0
# 31233              3807.0                    7.1                 732.0
# 71700                 3.0                    4.3                  16.0
# 55688               155.0                    6.0                 126.0
# 4597                539.0                    6.9                 266.0
# 14539               956.0                    7.2                 483.0
# 45175              1292.0                    5.8                 485.0
#
#       us_voters_rating us_voters_votes non_us_voters_rating  \
# 5561               6.6            47.0                  6.4
# 61883              4.8           121.0                  3.3
# 39988              3.4            41.0                  2.0
# 39498              4.6           161.0                  4.9
# 31233              7.3         41347.0                  7.3
# 71700              5.5            24.0                  5.4
# 55688              6.8          4368.0                  6.5
# 4597               7.7          2357.0                  7.4
# 14539              7.7         10117.0                  7.6
# 45175              5.9         13848.0                  6.2
#
#        non_us_voters_votes
# 5561                  36.0
# 61883                 36.0
# 39988                137.0
# 39498                 48.0
# 31233             111050.0
# 71700                105.0
# 55688               2907.0
# 4597                2009.0
# 14539              20610.0
# 45175              39267.0
#
# [10 rows x 70 columns]

# %%
pd.options.display.max_rows = 999
print(str(movies_usa.isna().sum()))
# Out:
# imdb_title_id                    0
# title                            0
# original_title                   0
# year                             0
# date_published                   0
# genre                            0
# duration                         0
# country                          0
# language                       345
# director                        34
# writer                         201
# production_company            1160
# actors                          26
# description                     74
# avg_vote                         0
# votes                            0
# budget                       18023
# usa_gross_income             20947
# worlwide_gross_income        20808
# metascore                    21902
# reviews_from_users             305
# reviews_from_critics          1876
# weighted_average_vote            0
# total_votes                      0
# mean_vote                        0
# median_vote                      0
# votes_10                         0
# votes_9                          0
# votes_8                          0
# votes_7                          0
# votes_6                          0
# votes_5                          0
# votes_4                          0
# votes_3                          0
# votes_2                          0
# votes_1                          0
# allgenders_0age_avg_vote     15700
# allgenders_0age_votes        15700
# allgenders_18age_avg_vote      335
# allgenders_18age_votes         335
# allgenders_30age_avg_vote        0
# allgenders_30age_votes           0
# allgenders_45age_avg_vote        1
# allgenders_45age_votes           1
# males_allages_avg_vote           1
# males_allages_votes              1
# males_0age_avg_vote          18261
# males_0age_votes             18261
# males_18age_avg_vote           755
# males_18age_votes              755
# males_30age_avg_vote             2
# males_30age_votes                2
# males_45age_avg_vote             2
# males_45age_votes                2
# females_allages_avg_vote         7
# females_allages_votes            7
# females_0age_avg_vote        18721
# females_0age_votes           18721
# females_18age_avg_vote        2162
# females_18age_votes           2162
# females_30age_avg_vote         180
# females_30age_votes            180
# females_45age_avg_vote         146
# females_45age_votes            146
# top1000_voters_rating           14
# top1000_voters_votes            14
# us_voters_rating                 2
# us_voters_votes                  2
# non_us_voters_rating             1
# non_us_voters_votes              1
# dtype: int64

# %%
movies_usa.shape
# Out:
# (28511, 70)

# %%
select =  ['imdb_title_id',
           'title',
           'original_title',
           'year',
           'genre',
           'director',
           'avg_vote',
           'votes',
           'budget',
           'males_allages_avg_vote',
           'males_allages_votes',
           'females_allages_avg_vote',
           'females_allages_votes']

movies_usa = movies_usa[select]

# %%
movies_usa.head()
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 3      tt0002101                                          Cleopatra
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 17     tt0003167                                     Amore di madre
# 19     tt0003471                                   Traffic in Souls
#
#                                        original_title  year             genre  \
# 0                                          Miss Jerry  1894           Romance
# 3                                           Cleopatra  1912    Drama, History
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912  Biography, Drama
# 17                                   Home, Sweet Home  1914             Drama
# 19                                   Traffic in Souls  1913      Crime, Drama
#
#                director  avg_vote  votes   budget  males_allages_avg_vote  \
# 0       Alexander Black       5.9    154      NaN                     6.2
# 3    Charles L. Gaskill       5.2    446  $ 45000                     5.1
# 5         Sidney Olcott       5.7    484      NaN                     5.7
# 17        D.W. Griffith       5.8    187      NaN                     5.7
# 19  George Loane Tucker       6.0    552   $ 5700                     5.9
#
#     males_allages_votes  females_allages_avg_vote  females_allages_votes
# 0                  97.0                       6.0                   35.0
# 3                 299.0                       5.9                   39.0
# 5                 354.0                       5.8                   31.0
# 17                124.0                       6.4                   16.0
# 19                399.0                       6.5                   54.0

# %%
movies_usa = pd.concat([movies_usa, movies_usa['genre'].str.get_dummies(',')], axis = 1)
movies_usa.head()
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 3      tt0002101                                          Cleopatra
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 17     tt0003167                                     Amore di madre
# 19     tt0003471                                   Traffic in Souls
#
#                                        original_title  year             genre  \
# 0                                          Miss Jerry  1894           Romance
# 3                                           Cleopatra  1912    Drama, History
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912  Biography, Drama
# 17                                   Home, Sweet Home  1914             Drama
# 19                                   Traffic in Souls  1913      Crime, Drama
#
#                director  avg_vote  votes   budget  males_allages_avg_vote  \
# 0       Alexander Black       5.9  154.0      NaN                     6.2
# 3    Charles L. Gaskill       5.2  446.0  $ 45000                     5.1
# 5         Sidney Olcott       5.7  484.0      NaN                     5.7
# 17        D.W. Griffith       5.8  187.0      NaN                     5.7
# 19  George Loane Tucker       6.0  552.0   $ 5700                     5.9
#
#     ...  Horror  Music  Musical  Mystery  Romance  Sci-Fi  Sport  Thriller  \
# 0   ...       0      0        0        0        1       0      0         0
# 3   ...       0      0        0        0        0       0      0         0
# 5   ...       0      0        0        0        0       0      0         0
# 17  ...       0      0        0        0        0       0      0         0
# 19  ...       0      0        0        0        0       0      0         0
#
#     War  Western
# 0     0        0
# 3     0        0
# 5     0        0
# 17    0        0
# 19    0        0
#
# [5 rows x 103 columns]
