# %%
! pip install numpy

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.1.4-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 6.7 MB/s eta 0:00:01
# Collecting numpy>=1.15.4
#   Downloading numpy-1.19.4-cp36-cp36m-manylinux2010_x86_64.whl (14.5 MB)
#      |████████████████████████████████| 14.5 MB 5.7 MB/s eta 0:00:01
# Collecting pytz>=2017.2
#   Downloading pytz-2020.4-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 7.3 MB/s eta 0:00:01
# Collecting python-dateutil>=2.7.3
#   Using cached python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting six>=1.5
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: numpy, pytz, six, python-dateutil, pandas
# Successfully installed numpy-1.19.4 pandas-1.1.4 python-dateutil-2.8.1 pytz-2020.4 six-1.15.0

# %%
print("hi")
# Out:
# hi

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

# %%
imdb_movies = pd.read_csv('IMDb movies.csv')
imdb_movies.head()
# Out:
# /home/daniel/.local/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
imdb_ratings = pd.read_csv('IMDb ratings.csv')
imdb_ratings.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                 13.0                     4.5                  4.0
# 1                 23.0                     6.6                 14.0
# 2                  4.0                     6.8                  7.0
# 3                 14.0                     6.1                 21.0
# 4                 82.0                     7.4                 77.0
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    5.7                  34.0               6.4
# 1                    6.4                  66.0               6.0
# 2                    5.4                  32.0               6.2
# 3                    4.9                  57.0               5.5
# 4                    6.9                 139.0               7.0
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# 0             51.0                   6.0                 70.0
# 1             96.0                   6.2                331.0
# 2             31.0                   5.9                123.0
# 3            207.0                   4.7                105.0
# 4            488.0                   7.0               1166.0
#
# [5 rows x 49 columns]

# %%
movies = pd.merge(imdb_movies, imdb_ratings, on = 'imdb_title_id')

# %%
movies.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ... females_30age_avg_vote  \
# 0     None                      Alexander Black  ...                    5.7
# 1     None                         Charles Tait  ...                    6.2
# 2      NaN                            Urban Gad  ...                    5.8
# 3  English                   Charles L. Gaskill  ...                    5.5
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...                    7.3
#
#   females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                13.0                    4.5                 4.0
# 1                23.0                    6.6                14.0
# 2                 4.0                    6.8                 7.0
# 3                14.0                    6.1                21.0
# 4                82.0                    7.4                77.0
#
#    top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                    5.7                  34.0              6.4
# 1                    6.4                  66.0              6.0
# 2                    5.4                  32.0              6.2
# 3                    4.9                  57.0              5.5
# 4                    6.9                 139.0              7.0
#
#   us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0            51.0                  6.0                 70.0
# 1            96.0                  6.2                331.0
# 2            31.0                  5.9                123.0
# 3           207.0                  4.7                105.0
# 4           488.0                  7.0               1166.0
#
# [5 rows x 70 columns]

# %%
movies_usa = movies[movies['country'] == 'USA']
movies_usa.sample(10)
# Out:
#       imdb_title_id                  title            original_title  year  \
# 28558     tt0111525  Due teneri angioletti           The Crazysitter  1994
# 13621     tt0063306            Senza sosta        The Mini-Skirt Mob  1968
# 8157      tt0047562    Il figlio di Kociss      Taza, Son of Cochise  1954
# 30169     tt0117731         Primo contatto  Star Trek: First Contact  1996
# 63461     tt1959526            Buttwhistle               Buttwhistle  2014
# 21902     tt0089036       Prigione modello                Doin' Time  1985
# 81418     tt6886080           To the Stars              To the Stars  2019
# 11185     tt0056267          La mia geisha                 My Geisha  1962
# 3064      tt0030550     Pals of the Saddle        Pals of the Saddle  1938
# 1305      tt0022938             Girl Crazy                Girl Crazy  1932
#
#       date_published                     genre  duration country  \
# 28558     1994-12-31      Comedy, Crime, Drama        92     USA
# 13621     1968-05-23             Action, Drama        82     USA
# 8157      1954-02-18    Action, Drama, Romance        79     USA
# 30169     1997-02-14  Action, Adventure, Drama       111     USA
# 63461     2014-04-25      Comedy, Crime, Drama        93     USA
# 21902     1985-05-19                    Comedy        81     USA
# 81418     2020-04-24                     Drama       109     USA
# 11185     1962-02-01    Comedy, Drama, Romance       119     USA
# 3064      1938-08-28  Action, Adventure, Drama        55     USA
# 1305      1932-03-25           Comedy, Musical        74     USA
#
#                 language           director  ... females_30age_avg_vote  \
# 28558            English   Michael McDonald  ...                    5.7
# 13621            English       Maury Dexter  ...                    5.0
# 8157    English, Spanish       Douglas Sirk  ...                    5.7
# 30169            English    Jonathan Frakes  ...                    7.6
# 63461            English   Tenney Fairchild  ...                    3.6
# 21902            English    George Mendeluk  ...                    6.3
# 81418            English    Martha Stephens  ...                    6.4
# 11185  English, Japanese       Jack Cardiff  ...                    6.8
# 3064             English     George Sherman  ...                    6.3
# 1305             English  William A. Seiter  ...                    6.5
#
#       females_30age_votes females_45age_avg_vote females_45age_votes  \
# 28558                32.0                    3.9                 9.0
# 13621                 9.0                    5.8                 7.0
# 8157                 15.0                    5.7                24.0
# 30169              4495.0                    7.7              2965.0
# 63461                21.0                    4.8                 6.0
# 21902                 5.0                    3.7                 3.0
# 81418                75.0                    5.8                28.0
# 11185               101.0                    7.0               150.0
# 3064                  9.0                    7.6                17.0
# 1305                 10.0                    5.4                16.0
#
#        top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 28558                    5.0                  49.0              5.8
# 13621                    4.6                  64.0              4.8
# 8157                     5.5                 103.0              5.6
# 30169                    7.1                 645.0              7.6
# 63461                    4.5                  50.0              4.4
# 21902                    4.5                  45.0              4.6
# 81418                    5.5                  49.0              6.6
# 11185                    6.0                 124.0              6.6
# 3064                     5.8                  47.0              6.6
# 1305                     6.3                  39.0              6.1
#
#       us_voters_votes non_us_voters_rating  non_us_voters_votes
# 28558           105.0                  4.6                107.0
# 13621           199.0                  4.8                 88.0
# 8157            197.0                  5.8                386.0
# 30169         30089.0                  7.5              45465.0
# 63461            97.0                  4.4                114.0
# 21902            77.0                  5.3                 95.0
# 81418           185.0                  6.1                359.0
# 11185           401.0                  6.5                523.0
# 3064            151.0                  5.1                 58.0
# 1305            141.0                  5.7                 33.0
#
# [10 rows x 70 columns]

# %%
pd.options.display.max_rows = 999
print(str(movies_usa.isna().sum()))
# Out:
# imdb_title_id                    0
# title                            0
# original_title                   0
# year                             0
# date_published                   0
# genre                            0
# duration                         0
# country                          0
# language                       345
# director                        34
# writer                         201
# production_company            1160
# actors                          26
# description                     74
# avg_vote                         0
# votes                            0
# budget                       18023
# usa_gross_income             20947
# worlwide_gross_income        20808
# metascore                    21902
# reviews_from_users             305
# reviews_from_critics          1876
# weighted_average_vote            0
# total_votes                      0
# mean_vote                        0
# median_vote                      0
# votes_10                         0
# votes_9                          0
# votes_8                          0
# votes_7                          0
# votes_6                          0
# votes_5                          0
# votes_4                          0
# votes_3                          0
# votes_2                          0
# votes_1                          0
# allgenders_0age_avg_vote     15700
# allgenders_0age_votes        15700
# allgenders_18age_avg_vote      335
# allgenders_18age_votes         335
# allgenders_30age_avg_vote        0
# allgenders_30age_votes           0
# allgenders_45age_avg_vote        1
# allgenders_45age_votes           1
# males_allages_avg_vote           1
# males_allages_votes              1
# males_0age_avg_vote          18261
# males_0age_votes             18261
# males_18age_avg_vote           755
# males_18age_votes              755
# males_30age_avg_vote             2
# males_30age_votes                2
# males_45age_avg_vote             2
# males_45age_votes                2
# females_allages_avg_vote         7
# females_allages_votes            7
# females_0age_avg_vote        18721
# females_0age_votes           18721
# females_18age_avg_vote        2162
# females_18age_votes           2162
# females_30age_avg_vote         180
# females_30age_votes            180
# females_45age_avg_vote         146
# females_45age_votes            146
# top1000_voters_rating           14
# top1000_voters_votes            14
# us_voters_rating                 2
# us_voters_votes                  2
# non_us_voters_rating             1
# non_us_voters_votes              1
# dtype: int64

# %%
movies_usa.shape
# Out:
# (28511, 70)

# %%
select =  ['imdb_title_id',
           'title',
           'original_title',
           'year',
           'date_published',
           'genre',
           'director',
           'avg_vote',
           'votes',
           'budget',
           'males_allages_avg_vote',
           'males_allages_votes',
           'females_allages_avg_vote',
           'females_allages_votes']

movies_usa = movies_usa[select]

# %% [markdown]
# Convert to date time

# %%
movies_usa['date_published'] = pd.to_datetime(movies_usa['date_published'], format='%Y-%m-%d', errors = 'coerce' )
movies_usa.dtypes
# Out:
# imdb_title_id                       object
# title                               object
# original_title                      object
# year                                object
# date_published              datetime64[ns]
# genre                               object
# director                            object
# avg_vote                           float64
# votes                                int64
# budget                              object
# males_allages_avg_vote             float64
# males_allages_votes                float64
# females_allages_avg_vote           float64
# females_allages_votes              float64
# dtype: object

# %%
def convert_budget(val):
    if pd.isnull(val):
        return np.nan
    
    if '$' in val:
        return int(val.replace('$', ''))
    elif 'GBP' in val:

# %%
movies_usa.head()
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 3      tt0002101                                          Cleopatra
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 17     tt0003167                                     Amore di madre
# 19     tt0003471                                   Traffic in Souls
#
#                                        original_title  year date_published  \
# 0                                          Miss Jerry  1894     1894-10-09
# 3                                           Cleopatra  1912     1912-11-13
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912           1913
# 17                                   Home, Sweet Home  1914     1914-05-17
# 19                                   Traffic in Souls  1913     1913-11-24
#
#                genre             director  avg_vote  votes   budget  \
# 0            Romance      Alexander Black       5.9    154      NaN
# 3     Drama, History   Charles L. Gaskill       5.2    446  $ 45000
# 5   Biography, Drama        Sidney Olcott       5.7    484      NaN
# 17             Drama        D.W. Griffith       5.8    187      NaN
# 19      Crime, Drama  George Loane Tucker       6.0    552   $ 5700
#
#     males_allages_avg_vote  males_allages_votes  females_allages_avg_vote  \
# 0                      6.2                 97.0                       6.0
# 3                      5.1                299.0                       5.9
# 5                      5.7                354.0                       5.8
# 17                     5.7                124.0                       6.4
# 19                     5.9                399.0                       6.5
#
#     females_allages_votes
# 0                    35.0
# 3                    39.0
# 5                    31.0
# 17                   16.0
# 19                   54.0

# %%
movies_usa = pd.concat([movies_usa, movies_usa['genre'].str.get_dummies(',')], axis = 1)
movies_usa.head()
# Out:
#    imdb_title_id                                              title  \
# 0      tt0000009                                         Miss Jerry
# 3      tt0002101                                          Cleopatra
# 5      tt0002199  From the Manger to the Cross; or, Jesus of Naz...
# 17     tt0003167                                     Amore di madre
# 19     tt0003471                                   Traffic in Souls
#
#                                        original_title  year             genre  \
# 0                                          Miss Jerry  1894           Romance
# 3                                           Cleopatra  1912    Drama, History
# 5   From the Manger to the Cross; or, Jesus of Naz...  1912  Biography, Drama
# 17                                   Home, Sweet Home  1914             Drama
# 19                                   Traffic in Souls  1913      Crime, Drama
#
#                director  avg_vote  votes   budget  males_allages_avg_vote  \
# 0       Alexander Black       5.9    154      NaN                     6.2
# 3    Charles L. Gaskill       5.2    446  $ 45000                     5.1
# 5         Sidney Olcott       5.7    484      NaN                     5.7
# 17        D.W. Griffith       5.8    187      NaN                     5.7
# 19  George Loane Tucker       6.0    552   $ 5700                     5.9
#
#     ...  Horror  Music  Musical  Mystery  Romance  Sci-Fi  Sport  Thriller  \
# 0   ...       0      0        0        0        1       0      0         0
# 3   ...       0      0        0        0        0       0      0         0
# 5   ...       0      0        0        0        0       0      0         0
# 17  ...       0      0        0        0        0       0      0         0
# 19  ...       0      0        0        0        0       0      0         0
#
#     War  Western
# 0     0        0
# 3     0        0
# 5     0        0
# 17    0        0
# 19    0        0
#
# [5 rows x 58 columns]
